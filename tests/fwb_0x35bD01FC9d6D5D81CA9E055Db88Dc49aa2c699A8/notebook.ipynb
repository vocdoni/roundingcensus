# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address              balance
# count                                         7343                 7343
# unique                                        7343                 3654
# top     0x000000000000000000000000000000000000dEaD  5000000000000000000
# freq                                             1                 1213

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#    balance  count
# 0        1     64
# 1        2      4
# 2        3      4
# 3        4      1
# 4        5      1
# 5        6      1
# 6        7      1
# 7        8      2
# 8        9      1
# 9       10      4
# 10      11      1
# 11      13      2
# 12      14      1
# 13      17      1
# 14      19      1
# 15      20      1
# 16      25      1
# 17      27      1
# 18      28      2
# 19      29      1
# 20      31      2
# 21      32      1
# 22      33      1
# 23      37      1
# 24      39      1
# 25      40      1
# 26      43      2
# 27      45      2
# 28      46      2
# 29      47      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address              balance
# count                                         7343                 7343
# unique                                        7343                  658
# top     0x000000000000000000000000000000000000dEaD  5000000000000000000
# freq                                             1                 1565

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#           balance  count
# 0               1    135
# 1             100      3
# 2             176      3
# 3             295      3
# 4             441      3
# 5            2000      3
# 6            7898      3
# 7           26817      3
# 8          243100      3
# 9       270167344      3
# 10     5071687001      3
# 11     7844375874      3
# 12   160000000000      3
# 13   479054149476      3
# 14   961495152140      3
# 15  1222832519370      3
# 16  2036964675754      3
# 17  3000000000000      3
# 18  3900721198646      3
# 19  4891436337636      3

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                      balance  count
# 657  60193887309220200000000      2
# 656  19000000000000000000000      3
# 655  14768000000000000000000      3
# 654  12400000000000000000000      3
# 653  10000000000000000000000      3
# 652   9999000000000000000000      4
# 651   7900000000000000000000      3
# 650   5628000000000000000000      3
# 649   4203420099125644000000      3
# 648   4000000000000000000000      6
# 647   3500043659262858077950      3
# 646   3000000000000000000000      3
# 645   2500000000000000000000      6
# 644   2290000000000000000000      3
# 643   2000000000000000000000      9
# 642   1906250000000000000000      3
# 641   1700000000000000000000      3
# 640   1400000000000000000000      3
# 639   1270442412717084581548      3
# 638   1000000000000000000000     18

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                        address
# balance
# 5000000000000000000       1565
# 75000000000000000000      1180
# 996736457816349132         223
# 100000000000000000000      171
# 10000000000000000000       158
# 1                          135
# 6000000000000000000        123
# 70000000000000000000        81
# 59700000000000000000        72
# 49075222419305198898        58
# 20000000000000000000        55
# 200000000000000000000       49
# 79967558171850840751        48
# 1986044248036993484         45
# 1000000000000000000         45
# 80000000000000000000        44
# 54000000000000000000        43
# 5100000000000000000         37
# 76000000000000000000        33
# 78000000000000000000        30

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                          address
# balance
# 60193887309220200000000        2
# 75400161000000000000           3
# 75374300000000000000           3
# 75370000000000000000           3
# 75360000000000000000           3
# 75355678065142600000           3
# 75320000000000000000           3
# 75290000000000000000           3
# 75287419925810260000           3
# 75234672600000000000           3
# 75220000000000000000           3
# 75210000000000000000           3
# 75190000000000000000           3
# 75170000000000000000           3
# 75099000000000000000           3
# 75090000000000000000           3
# 75080000000000000000           3
# 75070000000000000000           3
# 75050000000000000000           3
# 75025551519117366200           3
