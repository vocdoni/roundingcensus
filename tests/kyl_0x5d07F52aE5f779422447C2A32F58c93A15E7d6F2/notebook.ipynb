# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address                 balance
# count                                         1248                    1248
# unique                                        1248                    1240
# top     0x001B9e1c869f307469ccCFA5c5bE4476436d65Fb  1000000000000000000000
# freq                                             1                       3

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#                   balance  count
# 0                       1      1
# 1                  300806      1
# 2                  367162      1
# 3                  382137      1
# 4                  630376      1
# 5          94780746529887      1
# 6        1142857142857144      1
# 7      536538430801889693      1
# 8      866571428571428571      1
# 9     1793268860000000000      1
# 10   71405967379055781191      1
# 11   75000000000000000000      1
# 12   84382300000000000000      1
# 13  100000000000000000000      2
# 14  100859060191172210641      1
# 15  106507103910387726376      1
# 16  114741428571428571428      1
# 17  129791065446167949044      1
# 18  142001361101622030320      1
# 19  149036307199386983349      1
# 20  179862428571428571428      1
# 21  205280733602543074907      1
# 22  267130890632724060000      1
# 23  280000000000000000000      1
# 24  281442045329575200000      1
# 25  307850929627128367338      1
# 26  310651034120401071032      1
# 27  313603621469094836759      1
# 28  337929209385461222853      1
# 29  347546650960737352228      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address                  balance
# count                                         1248                     1248
# unique                                        1248                      341
# top     0x001B9e1c869f307469ccCFA5c5bE4476436d65Fb  10000000000000000000000
# freq                                             1                       30

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#                   balance  count
# 0                       1      3
# 1                  382137      3
# 2        1142857142857144      3
# 3     1793268860000000000      3
# 4    84382300000000000000      3
# 5   100000000000000000000      6
# 6   179862428571428571428      3
# 7   280000000000000000000      3
# 8   300000000000000000000      6
# 9   370000000000000000000      3
# 10  389581899086675613000      3
# 11  400000000000000000000      6
# 12  405635249490000000000      3
# 13  490000000000000000000      3
# 14  500000000000000000000      3
# 15  507330000000000000000      3
# 16  561013100000000000000      3
# 17  600000000000000000000      6
# 18  603448600000000000000      3
# 19  664678370000000000000      3

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                          balance  count
# 340  902572227933032683658815159      1
# 339    2871380093523613800000000      3
# 338    1896654349491083443153626      3
# 337    1287088416050854220000000      3
# 336    1041991357740100000000000      3
# 335     947001157095322749437123      3
# 334     722473000003420806285089      3
# 333     693423307000000000000000      3
# 332     624188576364410200000000      3
# 331     568785650846239354907020      3
# 330     520834000000000000000000      3
# 329     507389000000000000000000      3
# 328     500093376500000000000000      3
# 327     499250000000000000000000      3
# 326     462987725957214591319170      3
# 325     417356239068278400000000      3
# 324     401887355400776969424000      3
# 323     382134000000000000000000      3
# 322     351276000000000000000000      3
# 321     327622000000000000000000      3

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                           address
# balance
# 10000000000000000000000        30
# 1000000000000000000000         21
# 2000000000000000000000         18
# 4000000000000000000000         18
# 6000000000000000000000         15
# 3000000000000000000000         15
# 40000000000000000000000        15
# 20000000000000000000000        15
# 30000000000000000000000        12
# 13000000000000000000000         9
# 200000000000000000000000        9
# 12000000000000000000000         9
# 800000000000000000000           9
# 1400000000000000000000          6
# 1300000000000000000000          6
# 1200000000000000000000          6
# 2100000000000000000000          6
# 130000000000000000000000        6
# 2200000000000000000000          6
# 2400000000000000000000          6

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                              address
# balance
# 902572227933032683658815159        1
# 39589803000000000000000            3
# 38000000000000000000000            3
# 37000000000000000000000            3
# 36022016600000000000000            3
# 35000000000000000000000            3
# 34994071600000000000000            3
# 34438110100000000000000            3
# 40059959500000000000000            3
# 34184478860135176000000            3
# 33103095829923727000000            3
# 33000000000000000000000            3
# 32640000000000000000000            3
# 29665707800000000000000            3
# 29338920700000000000000            3
# 29000000000139243082300            3
# 28434006814750000000000            3
# 34000000000000000000000            3
# 40203834100000000000000            3
# 40628965200000000000000            3
