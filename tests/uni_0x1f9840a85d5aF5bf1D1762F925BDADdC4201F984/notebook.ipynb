# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address                balance
# count                                       115812                 115812
# unique                                      115812                  59918
# top     0x0000000000000000000000000000000000000001  400000000000000000000
# freq                                             1                  33278

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#    balance  count
# 0        1    401
# 1        2      1
# 2        3      3
# 3        4      4
# 4        5      1
# 5        6      2
# 6        9      1
# 7       10      2
# 8       12      1
# 9       14      2
# 10      15      2
# 11      16      1
# 12      20      1
# 13      21      1
# 14      22      3
# 15      24      1
# 16      25      1
# 17      26      1
# 18      29      1
# 19      30      3
# 20      35      1
# 21      36      2
# 22      37      1
# 23      39      2
# 24      41      2
# 25      43      2
# 26      44      2
# 27      46      3
# 28      48      2
# 29      50      2

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address                balance
# count                                       115812                 115812
# unique                                      115812                  15227
# top     0x0000000000000000000000000000000000000001  399999999999999999974
# freq                                             1                  33293

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#    balance  count
# 0        1    469
# 1       90     21
# 2      189      4
# 3      235      4
# 4      345      9
# 5      439      3
# 6      635      3
# 7      799      3
# 8     1000      6
# 9     2000      3
# 10    3441      3
# 11    4000      3
# 12    4860      3
# 13    8192      3
# 14   10000      6
# 15   20000      3
# 16   29623      3
# 17   33334      4
# 18   60892      3
# 19   77441      3

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                            balance  count
# 15226  169363888381532217148655505      1
# 15225   64000000000000000000000000      3
# 15224   39761682193918000000000000      3
# 15223   11995923120295565885770000      6
# 15222   10000000000000000000000000      4
# 15221    9000000000000000000000000     10
# 15220    5000000000000000000000000      3
# 15219    3941469668159004949888958      3
# 15218    3000000000000000000000000      3
# 15217    2000000000000000000000000      3
# 15216    1842830000000000000000000      3
# 15215    1500000000000000000000000      3
# 15214    1002617001353713700000000      3
# 15213    1000000000000000000000000      3
# 15212     919814467743827859000000      3
# 15211     774494611096000000000000      3
# 15210     718008960000000000000000      3
# 15209     700000000000000000000000      6
# 15208     698207931641052078797912      3
# 15207     680000000000000000000000      3

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                         address
# balance
# 399999999999999999974     33293
# 200000000000000000000      4027
# 99999997680000000000       2922
# 299999999999999999900      1308
# 799999999999993536293      1229
# 49999998000000000000       1030
# 999999999999999800          835
# 9999626820000000000         677
# 149999968002771290700       525
# 1                           469
# 249999999999999999800       377
# 1999994100000000000         346
# 4999628473129005417         330
# 20000000000000000000        303
# 19999999999999999966        301
# 349958018760058531400       274
# 100000000000000000000       274
# 40000000000000000000        236
# 30000000000000000000        216
# 1199760000000000000000      194

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                              address
# balance
# 169363888381532217148655505        1
# 337500000000000000000              3
# 337800000000000000000              3
# 338217000691085000000              3
# 339600000000000000000              3
# 340067255584638921610              3
# 340200000000000000000              3
# 340243647308379655840              3
# 340874548550000000000              3
# 341100000000000000000              3
# 341300000000000000000              3
# 341814605000000000000              3
# 342300000000000000000              3
# 342764607642696416900              3
# 343260000000000000000              3
# 343900000000000000000              3
# 345094252540000000000              3
# 345522613020000000000              3
# 345967072160713400000              3
# 346000000000000000000              3
