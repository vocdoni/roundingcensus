# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address                balance
# count                                         1401                   1401
# unique                                        1401                     31
# top     0x00000000000080C886232E9b7EBBFb942B5987AA  999000000000000000000
# freq                                             1                   1365

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#                     balance  count
# 0          8721169365898104      1
# 1      53000000000000000000      1
# 2      55709492516126830056      1
# 3      99000000000000000000      3
# 4     100000000000000000000      3
# 5     214122159703868553155      1
# 6     244485811773713658648      1
# 7     355499028790040670577      1
# 8     400000000000000000000      1
# 9     452556731337786318367      1
# 10    496835941024635446722      1
# 11    499000000000000000000      1
# 12    500000000000000000000      2
# 13    800000000000000000000      1
# 14    842283889004521073882      1
# 15    900000000000000000000      1
# 16    999000000000000000000   1365
# 17   1000000000000000000000      2
# 18   1010000000000000000000      1
# 19   1010115733879013650638      1
# 20   1104569681658018987200      1
# 21   1319336687178103830794      1
# 22   1768892220456461703301      1
# 23   3864770447067305101800      1
# 24   4126871979233323156012      1
# 25   4495042039589637786883      1
# 26   9977891191183559632488      1
# 27  10321012149193367454328      1
# 28  18914939779029143013572      1
# 29  26853972190571474731360      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address                balance
# count                                         1401                   1401
# unique                                        1401                     13
# top     0x00000000000080C886232E9b7EBBFb942B5987AA  999000000000000000000
# freq                                             1                   1365

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#                     balance  count
# 0          8721169365898104      3
# 1      99000000000000000000      3
# 2     100000000000000000000      3
# 3     214122159700000000000      3
# 4     400000000000000000000      3
# 5     499000000000000000000      3
# 6     800000000000000000000      3
# 7     999000000000000000000   1365
# 8    1000000000000000000000      6
# 9    1768892220456461703301      3
# 10   4495042039589637786883      1
# 11   9977891191183559632488      3
# 12  26853972100000000000000      2

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                     balance  count
# 12  26853972100000000000000      2
# 11   9977891191183559632488      3
# 10   4495042039589637786883      1
# 9    1768892220456461703301      3
# 8    1000000000000000000000      6
# 7     999000000000000000000   1365
# 6     800000000000000000000      3
# 5     499000000000000000000      3
# 4     400000000000000000000      3
# 3     214122159700000000000      3
# 2     100000000000000000000      3
# 1      99000000000000000000      3
# 0          8721169365898104      3

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                          address
# balance
# 999000000000000000000       1365
# 1000000000000000000000         6
# 8721169365898104               3
# 99000000000000000000           3
# 100000000000000000000          3
# 214122159700000000000          3
# 400000000000000000000          3
# 499000000000000000000          3
# 800000000000000000000          3
# 1768892220456461703301         3
# 9977891191183559632488         3
# 26853972100000000000000        2
# 4495042039589637786883         1

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                          address
# balance
# 4495042039589637786883         1
# 26853972100000000000000        2
# 8721169365898104               3
# 99000000000000000000           3
# 100000000000000000000          3
# 214122159700000000000          3
# 400000000000000000000          3
# 499000000000000000000          3
# 800000000000000000000          3
# 1768892220456461703301         3
# 9977891191183559632488         3
# 1000000000000000000000         6
# 999000000000000000000       1365
