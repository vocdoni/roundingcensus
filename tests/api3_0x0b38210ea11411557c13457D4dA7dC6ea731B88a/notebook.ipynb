# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address  balance
# count                                        22292    22292
# unique                                       22292    18638
# top     0x000000000000000000000000000000000000dEaD        1
# freq                                             1      972

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#    balance  count
# 0        1    972
# 1        2     12
# 2        3      1
# 3        4      3
# 4        5      1
# 5        6      1
# 6        7      3
# 7        9      1
# 8       11      1
# 9       13      1
# 10      23      1
# 11      26      1
# 12      27      1
# 13      34      1
# 14      36      1
# 15      48      1
# 16      49      1
# 17      53      1
# 18      57      1
# 19      65      1
# 20      83      1
# 21      85      1
# 22      94      1
# 23     101      1
# 24     102      2
# 25     130      1
# 26     136      1
# 27     143      1
# 28     151      1
# 29     157      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address  balance
# count                                        22292    22292
# unique                                       22292     2866
# top     0x000000000000000000000000000000000000dEaD        1
# freq                                             1     1001

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#    balance  count
# 0        1   1001
# 1       48      5
# 2       83      6
# 3      100      6
# 4      173     10
# 5      244      4
# 6      300      8
# 7      400      7
# 8      498      5
# 9      583      4
# 10     693      5
# 11     782      4
# 12     800      4
# 13     900      4
# 14    1000     21
# 15    1831      4
# 16    2000     21
# 17    3000     12
# 18    3950      4
# 19    4000     12

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                          balance  count
# 2865  18274371000000000000000000      2
# 2864   1062228836035650598656706      4
# 2863    950000224655445023096832      4
# 2862    825394527701856751553400      1
# 2861    550000000000000000000000      4
# 2860    484546879283663942069200      4
# 2859    447056537137118958126800      4
# 2858    357287266252437984971717      4
# 2857    300000000000000000000000      4
# 2856    200000000000000000000000      8
# 2855    190644692053450143988914      4
# 2854    180000000000000000000000      4
# 2853    130000000000000000000000      4
# 2852    100009360000000000000000      4
# 2851    100000000000000000000000     12
# 2850     95671578087856952579996      5
# 2849     84529868183320000000000      4
# 2848     70000000000000000000000      4
# 2847     63642751484241370840098      4
# 2846     59867594000000000000000      4

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                         address
# balance
# 1                          1001
# 999999934464                258
# 1100000000000000            170
# 1000000000000000000         129
# 99857900000000000000        129
# 9999883945162800000         125
# 99243722267113              105
# 9999999950000                93
# 10000000000000000000         88
# 49991516462916001999         81
# 40000000000000000000         79
# 19974883130000000000         76
# 100000000000000000           76
# 400000000000000000000        75
# 9849254932079262             73
# 100000000000000000000        68
# 200000000000000000           66
# 1000000000000000000000       60
# 4995000000000000000          54
# 500000000000000000000        53

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                             address
# balance
# 825394527701856751553400          1
# 18274371000000000000000000        2
# 144116056460000000000             4
# 144419988551556339400             4
# 145073965900000000000             4
# 145380386160000000000             4
# 145494982987228087680             4
# 145743000000000000000             4
# 146445900000000000000             4
# 147279248070000000000             4
# 147466200000000000000             4
# 147900000000000000000             4
# 148396621830000000000             4
# 148500000000000000000             4
# 148676776690000000000             4
# 148839687340000000000             4
# 149150814020000000000             4
# 143967825641107613120             4
# 142500000000000000000             4
# 142400000000000000000             4
