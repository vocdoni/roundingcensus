# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address            balance
# count                                         9079               9079
# unique                                        9079               6641
# top     0x0000000000000000000000000000000000000001  10000000000000000
# freq                                             1                357

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#    balance  count
# 0        1    135
# 1        2      4
# 2        3      7
# 3        4      5
# 4        5      4
# 5        6      2
# 6        7      5
# 7        8      1
# 8        9      3
# 9       10      3
# 10      13      2
# 11      14      1
# 12      15      1
# 13      16      1
# 14      17      3
# 15      18      1
# 16      19      1
# 17      20      1
# 18      21      2
# 19      29      1
# 20      35      1
# 21      37      1
# 22      41      2
# 23      42      2
# 24      45      1
# 25      47      1
# 26      48      1
# 27      50      1
# 28      51      1
# 29      52      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address           balance
# count                                         9079              9079
# unique                                        9079              1500
# top     0x0000000000000000000000000000000000000001  9999517201069092
# freq                                             1               360

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#    balance  count
# 0        1    200
# 1       80      4
# 2      100      3
# 3      170      3
# 4      277      3
# 5      300      4
# 6      466      3
# 7      653      3
# 8      888      3
# 9     1000      3
# 10    1755      3
# 11    2559      3
# 12    4600      3
# 13    6505      3
# 14    7758      3
# 15    9033      3
# 16   20000      3
# 17   28986      3
# 18   71334      3
# 19  186269      3

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                        balance  count
# 1499  475645826754026252145523      3
# 1498  200000000000000000000000      3
# 1497   89983842218419589639498      3
# 1496   50015000000000000000000      3
# 1495   30836564087815540000000      3
# 1494   19461483038004916244653      3
# 1493   10000000000000000000000      3
# 1492    9043742465181246038100      3
# 1491    6259128952574483468469      3
# 1490    4853417119630000000000      3
# 1489    3375987930456871847303      3
# 1488    2790083366000000000000      3
# 1487    2000000000000000000000      3
# 1486    1946319681277055129400      3
# 1485    1829109885910000000000      3
# 1484    1312500000000000000000      3
# 1483    1038500000000000000000      3
# 1482    1000000000000000000000      6
# 1481     983555529779826548000      3
# 1480     888707720333377745127      3

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                      address
# balance
# 9999517201069092         360
# 5000000000000000         344
# 19999999999999765        222
# 1                        200
# 99999200000000000        154
# 1000000000000000000      134
# 37871240000000000        101
# 999000000000000           85
# 30000000000000000         70
# 40000000000000000         54
# 50000000000000000         53
# 10000000000000000         52
# 11000000000000000         42
# 14000000000000000         40
# 500000000000000           40
# 12378820232992700         39
# 11998029000000000         36
# 100000000000000000        33
# 1999742142561066950       33
# 8000000000000000          32

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                     address
# balance
# 69142237713217000         3
# 522000000000000000        3
# 514292135400000000        3
# 511000000000000000        3
# 510000000000000000        3
# 492590486160000000        3
# 490000000000000000        3
# 480000000000000000        3
# 467000000000000000        3
# 462655817000000000        3
# 431241173425000000        3
# 424910000000000000        3
# 423741585901460550        3
# 420334078072400000        3
# 420000000000000000        3
# 411709350000000000        3
# 531000000000000000        3
# 558660000000000000        3
# 561563000000000000        3
# 574727000000000000        3
