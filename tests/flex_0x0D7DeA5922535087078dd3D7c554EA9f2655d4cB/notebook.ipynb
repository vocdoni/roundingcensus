# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address           balance
# count                                           82                82
# unique                                          82                82
# top     0x0226fbfAe9b321E0C961BcDAFE7a4Cf7d570B6DF  4976069043400000
# freq                                             1                 1

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#                balance  count
# 0                39260      1
# 1                78004      1
# 2               222334      1
# 3         321553973290      1
# 4        4725312288040      1
# 5       17648077300000      1
# 6       24946587391610      1
# 7      176709394000000      1
# 8      236705000000000      1
# 9      489900980000000      1
# 10     565924585500000      1
# 11     656356955869930      1
# 12     716770548600000      1
# 13     857387542300000      1
# 14     930631892600000      1
# 15    2588240386000000      1
# 16    2862285132600000      1
# 17    4000000000000000      1
# 18    4690880166811626      1
# 19    4976069043400000      1
# 20    8213006486681195      1
# 21   48211774370000000      1
# 22   57270706376991472      1
# 23   90000000000000000      1
# 24  120917812685336952      1
# 25  270000000000000000      1
# 26  512070045104445550      1
# 27  528365781983950051      1
# 28  720000000000000000      1
# 29  800000000000000000      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address          balance
# count                                           82               82
# unique                                          82               13
# top     0x0226fbfAe9b321E0C961BcDAFE7a4Cf7d570B6DF  930631892600000
# freq                                             1                7

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#                     balance  count
# 0                     39260      7
# 1           176709394000000      7
# 2           930631892600000      7
# 3         48211774370000000      7
# 4        720000000000000000      7
# 5       2146022193815891198      7
# 6     859160189815978900000      7
# 7    1820000000000000000000      7
# 8    2165999999503122924475      7
# 9    4387500000000000000000      7
# 10   5783000000000000000000      7
# 11  19197000000000000000000      1
# 12  35311710896830340360192      4

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                     balance  count
# 12  35311710896830340360192      4
# 11  19197000000000000000000      1
# 10   5783000000000000000000      7
# 9    4387500000000000000000      7
# 8    2165999999503122924475      7
# 7    1820000000000000000000      7
# 6     859160189815978900000      7
# 5       2146022193815891198      7
# 4        720000000000000000      7
# 3         48211774370000000      7
# 2           930631892600000      7
# 1           176709394000000      7
# 0                     39260      7

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                          address
# balance
# 39260                          7
# 176709394000000                7
# 930631892600000                7
# 48211774370000000              7
# 720000000000000000             7
# 2146022193815891198            7
# 859160189815978900000          7
# 1820000000000000000000         7
# 2165999999503122924475         7
# 4387500000000000000000         7
# 5783000000000000000000         7
# 35311710896830340360192        4
# 19197000000000000000000        1

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                          address
# balance
# 19197000000000000000000        1
# 35311710896830340360192        4
# 39260                          7
# 176709394000000                7
# 930631892600000                7
# 48211774370000000              7
# 720000000000000000             7
# 2146022193815891198            7
# 859160189815978900000          7
# 1820000000000000000000         7
# 2165999999503122924475         7
# 4387500000000000000000         7
# 5783000000000000000000         7
