# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address               balance
# count                                          723                   723
# unique                                         723                   342
# top     0x00000000000000000000000000000131b789155b  25000000000000000000
# freq                                             1                   150

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#                 balance  count
# 0                     1      6
# 1                     7      1
# 2                   207      1
# 3                  5085      1
# 4                 37099      1
# 5         1990989884573      1
# 6        10036614275344      1
# 7        24588000000000      1
# 8       184498806468612      1
# 9       200788721246780      1
# 10      201325794930019      1
# 11     6908960015177357      1
# 12   100000000000000000      1
# 13   196844954428026691      1
# 14   248646147605671934      1
# 15   258736138262902281      1
# 16   275410100000000000      1
# 17   401590743577666440      1
# 18   500000000000000000      3
# 19  1000000000000000000     47
# 20  1000000000000000117      1
# 21  1000000000000000182      1
# 22  1000000000000000235      1
# 23  1040000000000000000      1
# 24  1109992621914624935      1
# 25  1122334455667789001      1
# 26  1337849095098840897      1
# 27  1554070522035971797      1
# 28  1806265410080036776      1
# 29  2000000000000000000      5

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address               balance
# count                                          723                   723
# unique                                         723                   116
# top     0x00000000000000000000000000000131b789155b  25000000000000000000
# freq                                             1                   150

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#                 balance  count
# 0                     1      7
# 1                   207      3
# 2         1990989884573      3
# 3       184498806468612      3
# 4      6908960015177357      3
# 5    248646100000000000      3
# 6    401590743577666440      4
# 7   1000000000000000000     53
# 8   1337849095000000000      3
# 9   2000000000000000000      8
# 10  2880000000000000000     10
# 11  3000000000000000000      3
# 12  3200000000000000000     17
# 13  3330000000000000000      3
# 14  3549593802000000000      4
# 15  4011399309207311827     15
# 16  5000000000000000000      6
# 17  5104637511773525836      5
# 18  6000000000000000000      3
# 19  7000000000000000000      6

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                       balance  count
# 115  576148697069605005212992      1
# 114   36083307272750000000000      2
# 113   20000000000000000000000      4
# 112   11158370000000000000000      3
# 111    6840000000000000000000      3
# 110    5535000000000000000000      3
# 109    4226487936000000000000      5
# 108    3893000000000000000000      3
# 107    3452800000000000000000      3
# 106    3191817734700000000000      3
# 105    2673790000000000000000      3
# 104    2192255000000000000000      3
# 103    2060698560000000000000      4
# 102    1781000000000000000000      5
# 101    1506842840000000000000      3
# 100    1336890000000000000000      3
# 99     1162000000000000000000      3
# 98     1005446903676507333750      4
# 97      960000000000000000000      8
# 96      800000000000000000016      3

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                        address
# balance
# 25000000000000000000       150
# 1000000000000000000         53
# 10000000000000000000        50
# 3200000000000000000         17
# 4011399309207311827         15
# 20000000000000000000        14
# 46000000000000000000        11
# 399000000000000000000       11
# 2880000000000000000         10
# 30000000000000000000         9
# 2000000000000000000          8
# 320000000000000000000        8
# 960000000000000000000        8
# 198520000000000000000        7
# 1                            7
# 12000000000000000000         6
# 200000000000000000000        6
# 7000000000000000000          6
# 34239230000000000000         6
# 5000000000000000000          6

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                           address
# balance
# 576148697069605005212992        1
# 36083307272750000000000         2
# 353953901581256548000           3
# 323200000000000000000           3
# 274256000000000000000           3
# 236995967250000000000           3
# 177000000000000000000           3
# 175000000000000000000           3
# 165000000000000000000           3
# 150000000000000000000           3
# 136657015670000000000           3
# 127000000000000000000           3
# 124284928000000000000           3
# 120000000000000000000           3
# 105504500000000000000           3
# 103520000000000000000           3
# 100560000000000000000           3
# 90000000000000000000            3
# 81336828800000000000            3
# 64898618294962947700            3
