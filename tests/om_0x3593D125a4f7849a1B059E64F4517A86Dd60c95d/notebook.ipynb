# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address  balance
# count                                         7609     7609
# unique                                        7609     6766
# top     0x000000000000084e91743124a982076C59f10084        1
# freq                                             1      325

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#    balance  count
# 0        1    325
# 1        2      1
# 2        3      1
# 3        4      2
# 4        7      1
# 5        8      1
# 6       10      1
# 7       11      2
# 8       30      1
# 9       31      1
# 10      38      1
# 11      40      1
# 12      50      1
# 13      70      1
# 14     328      1
# 15     531      1
# 16     873      1
# 17    1319      1
# 18    2720      1
# 19    2726      1
# 20    3425      1
# 21    4070      1
# 22    5120      1
# 23    5761      1
# 24    6149      1
# 25    7449      1
# 26    7875      1
# 27    8335      1
# 28    9505      1
# 29   10632      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address  balance
# count                                         7609     7609
# unique                                        7609     1738
# top     0x000000000000084e91743124a982076C59f10084        1
# freq                                             1      334

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#    balance  count
# 0        1    334
# 1       30      5
# 2       70      3
# 3      873      4
# 4     3425      3
# 5     5761      3
# 6     7875      3
# 7    10000      3
# 8    15783      3
# 9    20000      6
# 10   27447      3
# 11   30000      3
# 12   39960      3
# 13   40000      6
# 14   49584      3
# 15   50000      3
# 16   56790      3
# 17   60000      4
# 18   70000      3
# 19   82908      3

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                           balance  count
# 1737  160504541000000000000000000      1
# 1736   37099894000000000000000000      3
# 1735   26600000000000000000000000      3
# 1734   17397295000000000000000000      3
# 1733   16551702980000000000000000      3
# 1732   13055816688201253839982800      3
# 1731   11696263060000000000000000      3
# 1730   10999990000000000000000000      3
# 1729   10199260000000000000000000      3
# 1728    9332921076000000000000000      3
# 1727    8847603236000000000000000      3
# 1726    8293741000000000000000000      3
# 1725    7567592314000000000000000      3
# 1724    7323188000000000000000000      3
# 1723    6096544488615430700000000      3
# 1722    4482466225996610000000000      1
# 1721    2084503303897920235900000      3
# 1720    1938994216834360777749000      3
# 1719    1500000000000000000000000      3
# 1718    1361341977900000000000000      3

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                           address
# balance
# 1                             334
# 99854138717564194600           60
# 200000000000000000000          57
# 300000000000000000000          50
# 999999999999999781224          46
# 999999999999475712             45
# 600000000000000000000          34
# 1000000000000000000000         31
# 498029657375807300000          30
# 4000000000000000000000         29
# 3000000000000000000000         27
# 100000000000000000000000       27
# 10000000000000000000000        27
# 5000000000000000000000         26
# 2500000000000000000000         24
# 1400000000000000000000         24
# 800000000000000000000          21
# 200000000000000000             21
# 50000000000000000000           21
# 140000000000000000000          20

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                              address
# balance
# 160504541000000000000000000        1
# 4482466225996610000000000          1
# 946641134017310000000              3
# 940000000000000000000              3
# 933995033296000000000              3
# 930000000000000000000              3
# 928100000000000000000              3
# 920989860630000000000              3
# 920000000000000000000              3
# 909008000000000000000              3
# 904500000000000000000              3
# 17405785641000000000000            3
# 896803438930117677200              3
# 896060000000000000000              3
# 889000000000000000000              3
# 888000000000000000000              3
# 883000000000000000000              3
# 17578210000000000000000            3
# 877790195830000000000              3
# 875000000000000000000              3
