# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address  balance
# count                                         1725     1725
# unique                                        1725     1539
# top     0x000000000000000000000000000000000000dEaD        1
# freq                                             1       45

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#        balance  count
# 0            1     45
# 1            2      1
# 2            3      2
# 3            5      3
# 4            7      1
# 5           14      1
# 6           16      1
# 7           21      1
# 8           38      1
# 9         1088      1
# 10        2429      1
# 11        3592      1
# 12        5242      1
# 13        5742      1
# 14        8192      1
# 15       11160      1
# 16       25376      1
# 17       44522      1
# 18       80531      1
# 19     1381843      1
# 20     2768223      1
# 21     4699615      1
# 22     5725382      1
# 23    16777216      1
# 24    17986139      1
# 25    78516004      1
# 26   241235969      1
# 27   801779610      1
# 28   954458260      1
# 29  1295306386      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address  balance
# count                                         1725     1725
# unique                                        1725      361
# top     0x000000000000000000000000000000000000dEaD        1
# freq                                             1       55

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#          balance  count
# 0              1     55
# 1             38      3
# 2           3592      3
# 3           8192      3
# 4          44522      3
# 5        2768223      3
# 6       16777216      3
# 7      241235969      3
# 8     1295306386      3
# 9     5179547000      3
# 10    6000000000      3
# 11   17160256082      3
# 12   28907031717      3
# 13   47969382115      3
# 14   74078050926      3
# 15  100000000000      6
# 16  200000000000      6
# 17  230000000000      3
# 18  259212000000      3
# 19  300000000000      9

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                       balance  count
# 360  306393375572369626230000      2
# 359   65260455914657422705565      3
# 358   30000000000000000000000      3
# 357   23200000000000000000000      3
# 356   20858725845000000000000      3
# 355   20000000000000000000000      3
# 354   19151133910094233464022      3
# 353   11000000000000000000000      3
# 352   10000000000000000000000      9
# 351    9566761779938362825805      3
# 350    8739604915184093088263      3
# 349    8333000000000000000000      3
# 348    7934953126286905756051      3
# 347    7337475690000000000000      3
# 346    7000000000000000000000      3
# 345    6366117384810653936845      3
# 344    6000000000000000000000      3
# 343    5605875969000000000000      3
# 342    5500000000000000000000      3
# 341    5339884400000000000000      3

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                         address
# balance
# 1                            55
# 100000000000000000000        44
# 49874993447301490000         41
# 500000000000000000000        24
# 300000000000000000000        24
# 200000000000000000000        23
# 1000000000000000000000       18
# 30000000000000000000         18
# 10000000000000000000         17
# 1000000000000000000          16
# 20000000000000000000         15
# 70000000000000000000         15
# 3000000000000000000000       15
# 180000000000000000000        15
# 600000000000000000000        15
# 60000000000000000000         15
# 50000000000000000000         15
# 220000000000000000000        12
# 800000000000000000000        12
# 150000000000000000000        12

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                           address
# balance
# 306393375572369626230000        2
# 158000000000000000000           3
# 152960888000000000000           3
# 140033966520000000000           3
# 140000000000000000000           3
# 139030000000000000000           3
# 139000000000000000000           3
# 158897509603428890000           3
# 136381220060000002000           3
# 113000000000000000000           3
# 112000000000000000000           3
# 109000000000000000000           3
# 108592476664447916700           3
# 106043000000000000000           3
# 104000000000000000000           3
# 117956424200000000000           3
# 161894727584733500000           3
# 166813403760000000000           3
# 171000000000000000000           3
# 351808849264500000000           3
