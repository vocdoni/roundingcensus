# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address               balance
# count                                         4112                  4112
# unique                                        4112                  3310
# top     0x000000000000084e91743124a982076C59f10084  68354430379746836480
# freq                                             1                   140

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#    balance  count
# 0        1     89
# 1        2      2
# 2        3      3
# 3        4      1
# 4        6      1
# 5        7      2
# 6        8      2
# 7        9      1
# 8       17      1
# 9       34      1
# 10      49      1
# 11     130      1
# 12     160      1
# 13     447      1
# 14     934      1
# 15     993      1
# 16    1073      1
# 17    1140      1
# 18    1229      1
# 19    1334      1
# 20    1361      1
# 21    1392      1
# 22    2242      1
# 23    2644      1
# 24    2703      1
# 25    2832      2
# 26    3057      1
# 27    3096      1
# 28    3114      1
# 29    3316      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address               balance
# count                                         4112                  4112
# unique                                        4112                   671
# top     0x000000000000084e91743124a982076C59f10084  68354430379746836480
# freq                                             1                   140

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#      balance  count
# 0          1    102
# 1         34      3
# 2        160      3
# 3        993      3
# 4       1000      3
# 5       1392      3
# 6       2000      3
# 7       3000      3
# 8       3310      3
# 9       5302      7
# 10      6000      3
# 11      7781      3
# 12     36863      3
# 13     54798      3
# 14     69144      3
# 15    228774      3
# 16   4337170      3
# 17  35000000      3
# 18  53239900      3
# 19  99799681      3

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                        balance  count
# 670  4079110865550000000000000      3
# 669  1539276736579353662096129      3
# 668  1000000000000000000000000      3
# 667   986175722203194699578470      3
# 666   825185504739217725597613      1
# 665   429126492044025292380944      3
# 664   291161805594651218217498      3
# 663   280000000000000000000000      3
# 662   188454798424000000000000      3
# 661   100000000000000000000000     15
# 660    90000000000000000000000      3
# 659    80000000000000000000000      3
# 658    73710995982788998176644      3
# 657    60000000000000000000000      3
# 656    53906692419100701257849      3
# 655    50000000000000000000000      3
# 654    48825755799327983043398      3
# 653    40000000000000000000000      6
# 652    30000000000000000000000      3
# 651    29133736497709139119544      3

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                         address
# balance
# 68354430379746836480        140
# 1                           102
# 1000000000000000000          75
# 100000000000000000000        48
# 30379746836480               41
# 20000000000000000000         39
# 4556835258368                36
# 10000000000000000000         35
# 61518987341772152832         34
# 146400000000000000000        33
# 300000000000000000000        31
# 1000000000000000000000       30
# 2000000000000000000          30
# 40000000000000000000         29
# 60000000000000000000         27
# 30000000000000000000         27
# 5000000000000000000          27
# 2954290011624070470          27
# 50000000000000000000         25
# 130000000000000000000        24

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                            address
# balance
# 825185504739217725597613         1
# 4079110865550000000000000        3
# 58270000000000000000             3
# 57750000000000000000             3
# 57600000000000000000             3
# 57000000000000000000             3
# 1803790000000000000000           3
# 1869734000000000000000           3
# 53912213200688516000             3
# 52099832549688718640             3
# 52000000000000000000             3
# 51000000000000000000             3
# 1994000000000000000000           3
# 49000000000000000000             3
# 2100000000000000000000           3
# 47000000000000000000             3
# 46000000000000000000             3
# 45000000000000000000             3
# 42000000000000000000             3
# 2172955861000000000000           3
