# %%
import pandas as pd
import json

# %%
with open('holders.json', 'r') as file:
    holders_data = json.load(file)

holders_df = pd.DataFrame(holders_data.items(), columns=['address', 'balance'])
holders_df['balance'] = holders_df['balance'].apply(lambda x: int(x))
print("Original holders data")
holders_df.describe()
# Out:
# Original holders data
#                                            address  balance
# count                                        11940    11940
# unique                                       11940     5992
# top     0x000000000000000000000000000000000000dEaD        1
# freq                                             1     2841

# %%
print("Grouped holders by common balances")
holders_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(30)
# Out:
# Grouped holders by common balances
#      balance  count
# 0          1   2841
# 1          2     29
# 2          3      1
# 3          4      1
# 4          5      2
# 5          6      1
# 6          9      1
# 7         14      1
# 8         16      1
# 9         37      1
# 10        41      1
# 11       170      1
# 12       501      1
# 13       816      1
# 14       876      1
# 15      1276      1
# 16      2722      1
# 17      3254      1
# 18     14320      1
# 19     17850      1
# 20     23468      1
# 21     35844      1
# 22     37899      1
# 23    345020      1
# 24    436557      1
# 25    504959      1
# 26    999741      1
# 27   1486956      1
# 28   2781152      1
# 29  10000000      1

# %%
with open('holders_rounded.json', 'r') as file:
    holders_rounded_data = json.load(file)

holders_rounded_df = pd.DataFrame(holders_rounded_data.items(), columns=['address', 'balance'])
holders_rounded_df['balance'] = holders_rounded_df['balance'].apply(lambda x: int(x))
print("Rounded holders data")
holders_rounded_df.describe()
# Out:
# Rounded holders data
#                                            address  balance
# count                                        11940    11940
# unique                                       11940     1177
# top     0x000000000000000000000000000000000000dEaD        1
# freq                                             1     2878

# %%
print("Number of address for the lowest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=True).head(20)
# Out:
# Number of address for the lowest balances groups
#       balance  count
# 0           1   2878
# 1          37      3
# 2         501      3
# 3        1276      3
# 4       14320      3
# 5       30000      3
# 6      436557      3
# 7     1486956      3
# 8    15117266      3
# 9    47018848      3
# 10   88784769      3
# 11  100000000      9
# 12  170000000      3
# 13  200000000     17
# 14  210000000      3
# 15  300000000     12
# 16  330000000      3
# 17  360000000      3
# 18  397147629      3
# 19  400000000      9

# %%
print("Number of address for the highest balances groups")
holders_rounded_df.groupby('balance').size().reset_index(name='count').sort_values('balance', ascending=False).head(20)
# Out:
# Number of address for the highest balances groups
#                        balance  count
# 1176  736451443819964058894000      2
# 1175  427346809058160176097024      3
# 1174  378323840969504622471984      3
# 1173  325296076924940000000000      3
# 1172  200000000000000000000000      3
# 1171  181492288826530978465566      3
# 1170  141028307847738375846960      2
# 1169  100000000000000000000000      6
# 1168   79234039416462098850124      3
# 1167   56064771192945129094382      3
# 1166   50000000000000000000000      3
# 1165   49481724696389264717361      3
# 1164   40000000000000000000000      3
# 1163   37807168121690000000000      3
# 1162   30000000000000000000000      3
# 1161   29331297637365755109492      3
# 1160   23979645818708966410000      3
# 1159   23000000000000000000000      3
# 1158   20986512086000000000000      3
# 1157   20000000000000000000000     12

# %%
print("Balances with more address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=False).head(20)
# Out:
# Balances with more address grouped
#                        address
# balance
# 1                         2878
# 9894808671975000          1076
# 991264929267025299         341
# 360000000000000000         325
# 99999999999999999          246
# 997424660                  139
# 67535733174220849600       108
# 488503469394798142          98
# 200000000000000000          94
# 1000000000000000000         94
# 1982934814485767589         85
# 9928762147125684940         45
# 2999999999999999999         45
# 100000000000000000000       42
# 932573630210                42
# 1297240216692486800         40
# 7000000000000000000         39
# 10000000000000000000        37
# 4983373085290503664         36
# 10000000000000              36

# %%
print("Balances with less address grouped")
holders_rounded_df.groupby(["balance"]).count().sort_values('address', ascending=True).head(20)
# Out:
# Balances with less address grouped
#                           address
# balance
# 736451443819964058894000        2
# 141028307847738375846960        2
# 57620260000000000000            3
# 57949048610796267000            3
# 59244483680000000000            3
# 59999999999999999999            3
# 60010175490944303892            3
# 61700000000000000000            3
# 61800000000000000000            3
# 61975298865585636000            3
# 62330357038919000000            3
# 65000000000000000000            3
# 65245507400000000000            3
# 65397000000000000000            3
# 66100000000000000000            3
# 66200000000000000000            3
# 66462550213656240000            3
# 67235273895000000000            3
# 67757917070094131400            3
# 69900000000000000000            3
